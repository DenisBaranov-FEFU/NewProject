# %%
a = True
Sname = input('Введите имя школьника:')
while a == True:
    Sage = int(input('Укажите количесвто полных лет:'))
    if Sage > 17:
        print('Укажите ученика помладше!')
    elif Sage < 7:
        print('Укажите ученика постарше!')
    else:
        a = False
a = True
while a == True:
    Ssex = input('Укажите пол ребенка, F или M:')
    if Ssex != 'F' and Ssex != 'M':
        print('Укажите пол ученика в соответствии с требованиями!')
    else:
        a = False
# Out:
# Введите имя школьника:Mike
# Укажите количесвто полных лет:17
# Укажите пол ребенка, F или M:M

# %%
import random

class Schoolboy:
    def __init__(self, name: str, sex:str, age:int):
        assert age > 6, f'{name} is {age} he is so young for school' #строки проверки для ввода через код
        assert age < 18, f'{name} is {age} he is so old for school'
        self.name = name
        self.age = age
        self.sex = sex
        grade = age - 6
        age = age
        self.grade = grade
        knowledge = random.uniform(50,70)
        happiness = random.uniform(50,70)
        fatigue = random.uniform(15,25)
        self.happiness = happiness
        self.knowledge = knowledge
        self.fatigue = fatigue
        
    def nextgrade(self):
        if self.age >= 17:
            print(self.name, 'is finished the school\n')
            self.age+=1
        else:
            self.age+=1   
            self.grade+=1
            print(self.name, 'got older\n')
        student.stats()
    
    def study(self):
        if (self.knowledge < 80) and (self.happiness > 15) and (self.fatigue < 70):
            self.knowledge *= 1 + random.uniform(.1,.25)
            self.happiness *= random.uniform(.5,.7)
            self.fatigue *= 1 + random.uniform(.4,.55)
            if self.knowledge > 100:
                self.knowledge = 100
            print(self.name, 'got smarter\n')
        else:
            print('Its time to stop, go outside sometimes\n')
        student.stats()
        
    def party(self):
        if (self.knowledge > 20): 
            self.happiness *= 1 + random.uniform(.15,.3)
            self.knowledge *= random.uniform(.6,.75)
            self.fatigue *= random.uniform(.4,.6)
            if self.happiness > 100:
                self.happiness = 100
            print(self.name, 'became happier\n')
        else:
            print('Maybe you try to start studing?\n')
        student.stats()
            
    def sleep(self):
        self.fatigue *= random.uniform(.35, .5)
        print(self.name, 'got enough sleep\n')
        student.stats()
        
    def exam(self):
        self.happiness *= random.uniform(.4,.6)
        self.fatigue *= 1 + random.uniform(.5,.6)
        if self.fatigue > 100:
                self.fatigue = 100
        print(self.name,'pass the exam\n')
        student.stats()
    
    def holiday(self):
        self.happines = 100
        self.fatigue = 0
        print(self.name, 'rested and had fun\n')
        student.stats()
        
        
    def stats(self):
        print('Name:', student.name)
        print('Grade:', student.grade)
        print('Age:', student.age)
        print('Sex:', student.sex)
        print('Knowledge:', round(student.knowledge,1), '%')
        print('Hapinnes:', round(student.happiness,1), '%')
        print('Fatigue:', round(student.fatigue), '%')

# %%
#student = Schoolboy('Mike','M', 15) #Ввод данных через код
student = Schoolboy(Sname,Ssex, Sage)

# %%
student.nextgrade()
# Out:
# Mike is finished the school
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 57.2 %
# Hapinnes: 60.6 %
# Fatigue: 19 %

# %%
student.party()
# Out:
# Mike became happier
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 40.2 %
# Hapinnes: 74.5 %
# Fatigue: 10 %

# %%
student.study()
# Out:
# Mike got smarter
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 49.9 %
# Hapinnes: 41.9 %
# Fatigue: 14 %

# %%
student.exam()
# Out:
# Mike pass the exam
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 49.9 %
# Hapinnes: 21.6 %
# Fatigue: 22 %

# %%
student.holiday()
# Out:
# Mike rested and had fun
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 49.9 %
# Hapinnes: 21.6 %
# Fatigue: 0 %

# %%
student.sleep()
# Out:
# Mike got enough sleep
#
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 49.9 %
# Hapinnes: 21.6 %
# Fatigue: 0 %

# %%
student.stats()
# Out:
# Name: Mike
# Grade: 11
# Age: 18
# Sex: M
# Knowledge: 49.9 %
# Hapinnes: 21.6 %
# Fatigue: 0 %
